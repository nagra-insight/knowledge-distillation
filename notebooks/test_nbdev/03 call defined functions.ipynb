# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Test if we can call library functions from a subfolder

# %%
from knowledge_distillation.io import ASSETS_PATH

# %%
ASSETS_PATH
# Out:
# PosixPath('/home/jupyterlab/ni-workspace/notebooks/notebooks/test_nbdev/../assets')

# %% [markdown]
# # Test if we can call library function defined in a subfolder, from a subfolder

# %%
from knowledge_distillation.nbdev_tests.defined_in_sub import defined_in_subfolder
defined_in_subfolder()
# Out:
# This function was defined in a subfolder

# %% [markdown]
# # Test if we can define the same function on different notebooks

# %%
from knowledge_distillation.nbdev_tests.multiple import defined_in_multiple_nbs
defined_in_multiple_nbs()
# Out:
# This function was defined on notebook 02

# %% [markdown]
# This is how the file looks like after the fn was re-defined
#
#     # AUTOGENERATED! DO NOT EDIT! File to edit: nbs/test_nbdev_define_in_subfolder/01 define in multiple_nbs 1.ipynb (unless otherwise specified).
#
#     __all__ = ['defined_in_multiple_nbs', 'defined_in_multiple_nbs']
#
#     # Cell
#
#     def defined_in_multiple_nbs():
#         print("This function was defined on notebook 01")
#
#     # Cell
#
#     def defined_in_multiple_nbs():
#         print("This function was defined on notebook 02")

# %% [markdown]
# # Conclusions
#
# - we can define functions in subfolders (allows flexibility, but should be used carefully  )
# - we can call library functions from subfolders
# - we can overwrite the same function in different notebooks (**WARNING: it can be a source of confusion!!**)
